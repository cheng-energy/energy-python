# %%
import pandas as pd
# 一次性配置好显示，以后不用重复写
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 25)

data = pd.read_csv(r"D:\浏览器下载\movies.csv")
# 用display输出，自动渲染整齐表格
display(data.head())
# Out:
#       电影ID             电影名称          类型        上映日期   时长   导演  \
# 0  MV00001     蜘蛛侠：英雄远征：金刚川  动作, 恐怖, 科幻  1984-05-07  173  张艺谋
# 1  MV00002  超胆侠2025：你好，李焕英3      悬疑, 犯罪  1988-10-27  189  张艺谋
# 2  MV00003      正义联盟2：少年的你3  喜剧, 恐怖, 悬疑  2011-05-04  225  郭敬明
# 3  MV00004            雷神：误杀      惊悚, 奇幻  1981-04-03  218  王家卫
# 4  MV00005          康斯坦丁：崛起  历史, 爱情, 动画  1996-02-19  130  王家卫
#
#                        主演   评分    评分人数
# 0  周星驰, 赵丽颖, 王宝强, 舒淇, 彭于晏  3.5  631595
# 1        刘诗诗, 杨紫, 李冰冰, 成龙  9.0  437921
# 2            杨紫, 张曼玉, 谢霆锋  4.0  394636
# 3       甄子丹, 谢霆锋, 胡歌, 张曼玉  3.6  165325
# 4       刘德华, 徐峥, 周星驰, 林依晨  9.0  285534
